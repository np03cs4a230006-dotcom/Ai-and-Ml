# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
from PIL import Image

# %%
image_colored = Image.open("/content/drive/MyDrive/Ai and Machine Learning/pikchu.png")

# %%
print("format:", image_colored.format)
print("size:", image_colored.size)
print("mode:", image_colored.mode )
# Out:
# format: PNG
# size: (840, 859)
# mode: RGBA

# %%
image_colored = image_colored.convert("RGB")
print(image_colored.mode)
# Out:
# RGB

# %% [markdown]
# # Gray Scale Image

# %%
image_grayed =image_colored.convert("L")
display(image_grayed)
# Out:
# <PIL.Image.Image image mode=L size=840x859>

# %%
print(image_grayed.size)
print(image_grayed.format)
print(image_grayed.mode)
# Out:
# (840, 859)
# None
# L

# %%
width, height = image_grayed.size
channels = len(image_grayed.getbands())

print(f"Image shape (gray): ({height}, {width}, {channels})")

image_size_grayed = width * height * 1
print(f"Image size (gray): {image_size_grayed}")
# Out:
# Image shape (gray): (859, 840, 1)
# Image size (gray): 721560

# %%
width, height = image_colored.size
channels = len(image_colored.getbands())

print(f"Image shape (RGB): ({height}, {width}, {channels})")

image_size_colored = width * height * 3
print(f"Image size (RGB): {image_size_colored}")
# Out:
# Image shape (RGB): (859, 840, 3)
# Image size (RGB): 2164680

# %% [markdown]
# # Converting to num py

# %%
import numpy as np
image_array_colored = np.array(image_colored)
image_array_colored.shape
# Out:
# (859, 840, 3)

# %%
import numpy as np
image_array_grayed = np.array(image_grayed)
image_array_grayed.shape
# Out:
# (859, 840)

# %% [markdown]
# # Accessing individual channels

# %%
red_channel = image_array_colored [: , : , 0]
print(red_channel)
display(red_channel)
# Out:
# [[255 255 255 ... 238 238 238]
#  [255 254 254 ... 237 237 237]
#  [255 254 254 ... 237 237 237]
#  ...
#  [254 254 254 ... 237 237 237]
#  [254 254 254 ... 237 237 237]
#  [255 255 255 ... 238 238 238]]
# array([[255, 255, 255, ..., 238, 238, 238],
#        [255, 254, 254, ..., 237, 237, 237],
#        [255, 254, 254, ..., 237, 237, 237],
#        ...,
#        [254, 254, 254, ..., 237, 237, 237],
#        [254, 254, 254, ..., 237, 237, 237],
#        [255, 255, 255, ..., 238, 238, 238]], dtype=uint8)

# %%
red_channel = image_array_colored.copy()
red_channel [:, :, 1] = 0
red_channel [:, :, 2] = 0
print(red_channel)
display(red_channel)
# Out:
# [[[255   0   0]
#   [255   0   0]
#   [255   0   0]
#   ...
#   [238   0   0]
#   [238   0   0]
#   [238   0   0]]
#
#  [[255   0   0]
#   [254   0   0]
#   [254   0   0]
#   ...
#   [237   0   0]
#   [237   0   0]
#   [237   0   0]]
#
#  [[255   0   0]
#   [254   0   0]
#   [254   0   0]
#   ...
#   [237   0   0]
#   [237   0   0]
#   [237   0   0]]
#
#  ...
#
#  [[254   0   0]
#   [254   0   0]
#   [254   0   0]
#   ...
#   [237   0   0]
#   [237   0   0]
#   [237   0   0]]
#
#  [[254   0   0]
#   [254   0   0]
#   [254   0   0]
#   ...
#   [237   0   0]
#   [237   0   0]
#   [237   0   0]]
#
#  [[255   0   0]
#   [255   0   0]
#   [255   0   0]
#   ...
#   [238   0   0]
#   [238   0   0]
#   [238   0   0]]]
# array([[[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [238,   0,   0],
#         [238,   0,   0],
#         [238,   0,   0]],
#
#        [[255,   0,   0],
#         [254,   0,   0],
#         [254,   0,   0],
#         ...,
#         [237,   0,   0],
#         [237,   0,   0],
#         [237,   0,   0]],
#
#        [[255,   0,   0],
#         [254,   0,   0],
#         [254,   0,   0],
#         ...,
#         [237,   0,   0],
#         [237,   0,   0],
#         [237,   0,   0]],
#
#        ...,
#
#        [[254,   0,   0],
#         [254,   0,   0],
#         [254,   0,   0],
#         ...,
#         [237,   0,   0],
#         [237,   0,   0],
#         [237,   0,   0]],
#
#        [[254,   0,   0],
#         [254,   0,   0],
#         [254,   0,   0],
#         ...,
#         [237,   0,   0],
#         [237,   0,   0],
#         [237,   0,   0]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [238,   0,   0],
#         [238,   0,   0],
#         [238,   0,   0]]], dtype=uint8)

# %%
green_channel = image_array_colored.copy()
green_channel [:, :, 0] = 0
green_channel [:, :, 2] = 0
print(green_channel)
display(green_channel)
# Out:
# [[[  0 255   0]
#   [  0 255   0]
#   [  0 255   0]
#   ...
#   [  0 238   0]
#   [  0 238   0]
#   [  0 238   0]]
#
#  [[  0 255   0]
#   [  0 254   0]
#   [  0 254   0]
#   ...
#   [  0 237   0]
#   [  0 237   0]
#   [  0 237   0]]
#
#  [[  0 255   0]
#   [  0 254   0]
#   [  0 254   0]
#   ...
#   [  0 237   0]
#   [  0 237   0]
#   [  0 237   0]]
#
#  ...
#
#  [[  0 254   0]
#   [  0 254   0]
#   [  0 254   0]
#   ...
#   [  0 237   0]
#   [  0 237   0]
#   [  0 237   0]]
#
#  [[  0 254   0]
#   [  0 254   0]
#   [  0 254   0]
#   ...
#   [  0 237   0]
#   [  0 237   0]
#   [  0 237   0]]
#
#  [[  0 255   0]
#   [  0 255   0]
#   [  0 255   0]
#   ...
#   [  0 238   0]
#   [  0 238   0]
#   [  0 238   0]]]
# array([[[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 238,   0],
#         [  0, 238,   0],
#         [  0, 238,   0]],
#
#        [[  0, 255,   0],
#         [  0, 254,   0],
#         [  0, 254,   0],
#         ...,
#         [  0, 237,   0],
#         [  0, 237,   0],
#         [  0, 237,   0]],
#
#        [[  0, 255,   0],
#         [  0, 254,   0],
#         [  0, 254,   0],
#         ...,
#         [  0, 237,   0],
#         [  0, 237,   0],
#         [  0, 237,   0]],
#
#        ...,
#
#        [[  0, 254,   0],
#         [  0, 254,   0],
#         [  0, 254,   0],
#         ...,
#         [  0, 237,   0],
#         [  0, 237,   0],
#         [  0, 237,   0]],
#
#        [[  0, 254,   0],
#         [  0, 254,   0],
#         [  0, 254,   0],
#         ...,
#         [  0, 237,   0],
#         [  0, 237,   0],
#         [  0, 237,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 238,   0],
#         [  0, 238,   0],
#         [  0, 238,   0]]], dtype=uint8)

# %%
blue_channel = image_array_colored.copy()
blue_channel [:, :, 0] = 0
blue_channel [:, :, 1] = 0
print(blue_channel)
display(blue_channel)
# Out:
# [[[  0   0 255]
#   [  0   0 255]
#   [  0   0 255]
#   ...
#   [  0   0 238]
#   [  0   0 238]
#   [  0   0 238]]
#
#  [[  0   0 255]
#   [  0   0 254]
#   [  0   0 254]
#   ...
#   [  0   0 237]
#   [  0   0 237]
#   [  0   0 237]]
#
#  [[  0   0 255]
#   [  0   0 254]
#   [  0   0 254]
#   ...
#   [  0   0 237]
#   [  0   0 237]
#   [  0   0 237]]
#
#  ...
#
#  [[  0   0 254]
#   [  0   0 254]
#   [  0   0 254]
#   ...
#   [  0   0 237]
#   [  0   0 237]
#   [  0   0 237]]
#
#  [[  0   0 254]
#   [  0   0 254]
#   [  0   0 254]
#   ...
#   [  0   0 237]
#   [  0   0 237]
#   [  0   0 237]]
#
#  [[  0   0 255]
#   [  0   0 255]
#   [  0   0 255]
#   ...
#   [  0   0 238]
#   [  0   0 238]
#   [  0   0 238]]]
# array([[[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 238],
#         [  0,   0, 238],
#         [  0,   0, 238]],
#
#        [[  0,   0, 255],
#         [  0,   0, 254],
#         [  0,   0, 254],
#         ...,
#         [  0,   0, 237],
#         [  0,   0, 237],
#         [  0,   0, 237]],
#
#        [[  0,   0, 255],
#         [  0,   0, 254],
#         [  0,   0, 254],
#         ...,
#         [  0,   0, 237],
#         [  0,   0, 237],
#         [  0,   0, 237]],
#
#        ...,
#
#        [[  0,   0, 254],
#         [  0,   0, 254],
#         [  0,   0, 254],
#         ...,
#         [  0,   0, 237],
#         [  0,   0, 237],
#         [  0,   0, 237]],
#
#        [[  0,   0, 254],
#         [  0,   0, 254],
#         [  0,   0, 254],
#         ...,
#         [  0,   0, 237],
#         [  0,   0, 237],
#         [  0,   0, 237]],
#
#        [[  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255],
#         ...,
#         [  0,   0, 238],
#         [  0,   0, 238],
#         [  0,   0, 238]]], dtype=uint8)

# %% [markdown]
# # Extracting sub image from an image Array

# %%
row_100 = image_array_colored[100, :, :]
print(row_100)
display(row_100)
# Out:
# [[239 239 239]
#  [238 238 238]
#  [238 238 238]
#  ...
#  [254 254 254]
#  [254 254 254]
#  [254 254 254]]
# array([[239, 239, 239],
#        [238, 238, 238],
#        [238, 238, 238],
#        ...,
#        [254, 254, 254],
#        [254, 254, 254],
#        [254, 254, 254]], dtype=uint8)

# %% [markdown]
# # image cropping

# %%
left = 100
upper = 50
right = 200
lower = 200
cropped_image = image_colored.crop((left, upper, right, lower))
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x150>

# %% [markdown]
# # Principal Component Analysis (PCA )

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

image = Image.open("/content/drive/MyDrive/Ai and Machine Learning/cameraman.png")
